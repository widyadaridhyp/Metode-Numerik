# %%
def TPEP (x,h,f,x_points): # Definisi rumus turunan pertama dari TPEP ((1/(2*h))*(-3*f(x)+4*f(x+h)-f(x+2*h)))
    turunan = ((1/(2*h))*(-3*f[x_points.index(x)]+4*f[x_points.index(round(x+h,2))]-f[x_points.index(round(x+(2*h),2))]))
    return turunan
def TPMP (x,h,f,x_points): # Definisi rumus turunan pertama dari TPMP ((1/(2*h))*(f(x+h)-f(x-h)))
    turunan = (1/(2*h))*(f[x_points.index(round(x+h,2))]-f[x_points.index(round(x-h,2))]) 
    return turunan
def FPEP (x,h,f,x_points):# Definisi rumus turunan dari FPEP ((1/(12*h))*(-25*f(x)+48*f(x+h)-36*f(x+2*h)+16*f(x+3*h)-3*f(x+4*h)))
    turunan = (1/(12*h))*(-25*f[x_points.index(x)]+48*f[x_points.index(round(x+h,2))]-36*f[x_points.index(round(x+(2*h),2))]+16*f[x_points.index(round(x+(3*h),2))]-3*f[x_points.index(round(x+(4*h),2))]) 
    return turunan
def FPMP (x,h,f,x_points): # Definisi rumus turunan pertama dari FPMP ((1/(12*h))*(f(x-2*h)-8*f(x-h)+8*f(x+h)-f(x+2*h)))
    turunan = (1/(12*h))*(f[x_points.index(round(x-(2*h),2))]-8*f[x_points.index(round(x-h,2))]+8*f[x_points.index(round(x+h,2))]-f[x_points.index(round(x+(2*h),2))])
    return turunan

def STPEP(x,h,f,x_points): #Definisi rumus turunan kedua dari TPEP (1/(2*h**2))*(f(x+2h)-2f(x+1)+f(x))
    turunan = (1/(h**2))*(f[x_points.index(round(x+(2*h),2))]-2*f[x_points.index(round(x+h,2))]+f[x_points.index(x)])
    return turunan
def STPMP(x,h,f,x_points): #Definisi rumus turunan kedua dari TPMP (1/(h**2))*(f(x-h)-2f(x)+f(x+h))
    turunan = (1/(h**2))*(f[x_points.index(round(x-h,2))]-2*f[x_points.index(x)]+f[x_points.index(round(x+h,2))])
    return turunan
def SFPMP(x,h,f,x_points): #Definisi rumus turunan kedua dari FPMP (1/(12h**2))*(-f(x-2h)+16f(x-h)-30f(x)+16f(x+h)-f(x+2h))
    turunan = (1/(12*h**2))*((-1)*f[x_points.index(round(x-(2*h)),2)]+16*f[x_points.index(round(x-h,2))]-30*f[x_points.index(x)]+16*f[x_points.index(round(x+h,2))]-1*f[x_points.index(round(x+(2*h),2))])
    return turunan

def TFPEP(x,h,f,x_points): #Definisi rumus turunan ketiga dari FPEP (1/(2h**3))*(-5f(x)+18f(x+h)-24f(x+2h)+14f(x+3h)-3f(x+4h))
    turunan = (1/(2*h**3))*((-5)*f[x_points.index(x)]+18*f[x_points.index(round(x+h2))]-24*f[x_points.index(round(x+(2*h),2))]+14*f[x_points.index(round(x+(3*h),2))]-3*f[x_points.index(round(x+(4*h),2))])
    return turunan
def TFPMP(x,h,f,x_points): #Definisi rumus turunan ketiga dari FPMP (1/(2h**3))*(f(x+2h)-2f(x+h)+2f(x-h)-f(x-2h))
    turunan = (1/(2*h**3))*(f[x_points.index(round(x+(2*h),2))]-2*f[x_points.index(round(x+h,2))]+2*f[x_points.index(round(x-h,2))]-f[x_points.index(round(x-(2*h),2))])
    return turunan

               
while True: #Buat loop berulang biar bisa di run lagi buat nilai x yang lain
    print('---------------------------------------------------------------------------------')
    try_ = int(input('Mau coba jalanin? (1 = Ya, 2 = Tidak): ')) #kasih pilihan agar dapat diberhentikan
    if try_ == 1: #Opsi untuk melanjutkan program
        titik_x = eval(input('Masukkan titik-titik x: ')) #input list x yang ada di tabel
        titik_y= eval(input('Masukkan titik-titik y: ')) #input list y yang terdapat pada tabel
        x0 = eval(input('Masukkan titik di mana nilai turunan fungsinya akan diaproksimasi: ')) #Input titik yang ingin diaproksimasikan
        h = eval(input('Masukkan stepsize: ')) #Input jarak antarnilai x
        opsi_turunan = int(input('Pilih turunan ke berapa? (1/2/3): ')) #Opsi untuk turunan
        if opsi_turunan == 1:
            opsi = int(input('Pilih metode apa? (1 = TPEP, 2 = TPMP, 3 = FPEP, 4 = FPMP): ')) #Opsi untuk metode yang digunakan
            if opsi == 1:
                print('Turunan dari f di x0 = {0} adalah: '.format(x0))
                print("f'({0}) = {1:.7f} (Three Point Endpoint)".format(x0,TPEP(x0,h,titik_y,titik_x))) #Print hasil turunan pertama TPMP
            elif opsi == 2:
                print('Turunan dari f di x0 = {0} adalah: '.format(x0))
                print("f'({0}) = {1:.7f} (Three Point Midpoint)".format(x0,TPMP(x0,h,titik_y,titik_x))) #Print hasil turunan pertama TPMP
            elif opsi == 3:
                print('Turunan dari f di x0 = {0} adalah: '.format(x0))
                print("f'({0}) = {1:.7f} (Five Point Endpoint)".format(x0,FPEP(x0,h,titik_y,titik_x))) #Print hasil turunan pertama FPEP
            elif opsi == 4:
                print('Turunan dari f di x0 = {0} adalah: '.format(x0))
                print("f'({0}) = {1:.7f} (Five Point Midpoint)".format(x0,FPMP(x0,h,titik_y,titik_x))) #Print hasil turunan pertama FPMP   

        elif opsi_turunan == 2:
            opsi = int(input('Pilih metode apa? (1 = TPEP, 2 = TPMP, 3 = FPMP): ')) #Opsi untuk turunan
            if opsi == 1:
                print('Turunan kedua dari f di x0 = {0} adalah: '.format(x0))
                print("f''({0}) = {1:.7f} (Three Point Endpoint)".format(x0,STPEP(x0,h,titik_y,titik_x))) #Print hasil turunan kedua TPEP
            elif opsi == 2:
                print('Turunan kedua dari f di x0 = {0} adalah: '.format(x0))
                print("f''({0}) = {1:.7f} (Three Point Midpoint)".format(x0,STPMP(x0,h,titik_y,titik_x))) #Print hasil turunan kedua TPMP
            elif opsi == 3:
                print('Turunan kedua dari f di x0 = {0} adalah: '.format(x0))
                print("f''({0}) = {1:.7f} (Five Point Midpoint)".format(x0,SFPMP(x0,h,titik_y,titik_x))) #Print hasil turunan kedua FPMP

        elif opsi_turunan == 3:
            opsi = int(input('Pilih metode apa? (1 = FPEP, 2 = FPMP): ')) #Opsi untuk turunan 
            if opsi == 1:
                print('Turunan ketiga dari f di x0 = {0} adalah: '.format(x0))
                print("f'''({0}) = {1:.7f} (Five Point Endpoint)".format(x0,TFPEP(x0,h,titik_y,titik_x))) #Print hasil turunan ketiga FPEP
            elif opsi == 2:
                print('Turunan ketiga dari f di x0 = {0} adalah: '.format(x0))
                print("f'''({0}) = {1:.7f} (Five Point Midpoint)".format(x0,TFPMP(x0,h,titik_y,titik_x))) #Print hasil turunan ketiga FPMP
               
    elif try_ == 2:
        break
# Out:
# ---------------------------------------------------------------------------------
# Mau coba jalanin? (1 = Ya, 2 = Tidak): 1
# Masukkan titik-titik x: [23,25,27,29,31]
# Masukkan titik-titik y: [31.19928,-0.15139,-279.72147,4.92198,-1.0934]
# Masukkan titik di mana nilai turunan fungsinya akan diaproksimasi: 25
# Masukkan stepsize: 2
# Pilih turunan ke berapa? (1/2/3): 1
# Pilih metode apa? (1 = TPEP, 2 = TPMP, 3 = FPEP, 4 = FPMP): 2
# Turunan dari f di x0 = 25 adalah:
# f'(25) = -77.7301875 (Three Point Midpoint)
# ---------------------------------------------------------------------------------
# Mau coba jalanin? (1 = Ya, 2 = Tidak): 1
# Masukkan titik-titik x: [1.8,1.9,2.0,2.1,2.2]
# Masukkan titik-titik y: [10.889365,12.703199,14.778112,17.148957,19.855030]
# Masukkan titik di mana nilai turunan fungsinya akan diaproksimasi: 2.0
# Masukkan stepsize: 0.1
# Pilih turunan ke berapa? (1/2/3): 1
# Pilih metode apa? (1 = TPEP, 2 = TPMP, 3 = FPEP, 4 = FPMP): 4
# ...

# %% [markdown]
# Program ini untuk print input dari user yang mana inputnya berupa pilihan menjalankan program atau tidak, data titik x, data titik y, x yang ingin diaproksimasi, perbedaan antarnilai data x, opsi metode, dan opsi turunan.
#
# Berikut ini adalah algoritmanya.
# 1. Mendefinisikan seluruh rumus turunan pertama, kedua, dan ketiga. Dengan menggunakan titik aproksimasi, perbedaan antarnilai data x, data nilai x, dan data nilai y. Di saat ini, akan menggunakan .index untuk mendeteksi nilai x yang berada dalam f(x). Nantinya f(x) ini akan di arahkan ke nilai data y menggunakan posisi pada list nilai data x. Kemudian, akan digunakan round untuk membulatkan nilai hasil penjumlahan atau pengurangan ketika mencari nilai x dalam f(x), sehingga posisi x nanti akan terdefinisi dengan baik.
# 2. Menggunakan while True untuk pengulangan yang nantinya akan diberikan opsi untuk menjalankan dan memberhentitkan program
# 3. Menginput nilai x yang akan diaproksimasi, data nilai x, data nilai y, dan h (perbedaan antarnilai data x atau selisih tiap x)
# 4. Akan terdapat opsi yang digunakan untuk memilih turunan keberapa yang diinginkan (pertama, kedua, atau ketiga).
# 5. Akan terdapat opsi yang digunakan untuk memilih metode yang akan digunakan TPEP, TPMP, FPEP, atau FPMP.
# 6. Kemudian akan diarahkan untuk mencetak hasil nilai aproksimasi x yang mana telah didefinisikn sebelum while loop.
# 7. Setelah diprint akan mengulang lagi karena menggunakan while True. Jika memilih pilihan 2 akan diarahkan untuk memberhentikan program.
